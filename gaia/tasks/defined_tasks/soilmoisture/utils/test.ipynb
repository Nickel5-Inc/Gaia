# %%
from datetime import datetime, timezone, timedelta
import os

from gaia.tasks.defined_tasks.soilmoisture.utils.soil_apis import get_soil_data
try:        
    bbox = [-75.50965247716238, -4.278356939582369, -74.50965247716238, -3.278356939582369]
    output_file = get_soil_data(bbox)
    print(f"Data saved to: {output_file}")
except ValueError as e:
    print(f"Error: {str(e)}")
# Out:
# === Starting Data Collection ===
#
# === Processing Sentinel Data ===
# Searching for Sentinel data for November 2024
# Found 6 potential scenes
# Found data for 2024-11-15 with 3.0% cloud cover
# Found data for 2024-11-15 with 15.0% cloud cover
# Found data for 2024-11-15 with 22.0% cloud cover
# Found data for 2024-11-15 with 29.0% cloud cover
# Found data for 2024-11-05 with 50.0% cloud cover
# Found data for 2024-11-05 with 50.0% cloud cover
# No data found for current month, trying previous month...
# Searching for Sentinel data for October 2024
# Found 13 potential scenes
# Found data for 2024-10-19 with 6.0% cloud cover
# Found data for 2024-10-19 with 13.0% cloud cover
# Found data for 2024-10-31 with 23.0% cloud cover
# Found data for 2024-10-16 with 24.0% cloud cover
# Found data for 2024-10-01 with 29.0% cloud cover
# Found data for 2024-10-31 with 31.0% cloud cover
# Found data for 2024-10-31 with 34.0% cloud cover
# Found data for 2024-10-16 with 34.0% cloud cover
# Found data for 2024-10-16 with 36.0% cloud cover
# Found data for 2024-10-16 with 40.0% cloud cover
# Found data for 2024-10-01 with 41.0% cloud cover
# Found data for 2024-10-31 with 44.0% cloud cover
# Found data for 2024-10-06 with 49.0% cloud cover
# No suitable Sentinel-2 data found in current or previous month
# Failed to fetch Sentinel data
# Data saved to: None
